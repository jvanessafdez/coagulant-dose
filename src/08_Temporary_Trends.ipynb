# %% [markdown]
# # ANÁLISIS DE TENDENCIAS TEMPORALES

# %%
# Importación de librerías necesarias
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data_edit/df_edit_with_met.csv',sep=',', encoding='latin-1', index_col=0, low_memory=False, parse_dates=['FECHA'])

# %%
df['Año'] = df['FECHA'].dt.year

# %% [markdown]
# ## Años 2013-2015

# %%
def trend(start_year,end_year,parameter):
    plt.figure(figsize=(12, 6))
    for year in range(start_year, end_year):
        data_year = df[df['Año'] == year]
        plt.plot(data_year['FECHA'], data_year[parameter], label=year)

    plt.xlabel('FECHA')
    plt.ylabel(parameter)
    plt.title(f'TENDENCIA TEMPORAL DE {parameter}')
    plt.legend(title='Año')
    plt.show()

# %% [markdown]
# ### Agua Cruda

# %%
trend(2013,2016,'AGUA_CRUDA_P.H')

# %%
trend(2013,2016,'AGUA_CRUDA_NTU')

# %%
trend(2013,2016,'AGUA_CRUDA_COLOR')

# %%
trend(2013,2016,'CAUDAL')

# %% [markdown]
# En el análisis de los parámetros de agua cruda, se observa una tendencia definida en los indicadores de turbiedad y color desde mayo hasta septiembre. Durante estos meses, se registra una disminución notable en los valores de estos parámetros. Sin embargo, se evidencia un incremento en los mismos indicadores durante los meses de noviembre y febrero. Esta fluctuación cíclica muestra la variabilidad estacional inherente a estos parámetros de calidad del agua.

# %% [markdown]
# ### Agua Tratada

# %%
trend(2013,2016,'AGUA_TRATADA_P.H')

# %%
trend(2013,2016,'AGUA_TRATADA_NTU')

# %%
trend(2013,2016,'AGUA_TRATADA_COLOR')

# %%
trend(2013,2016,'AGUA_TRATADA_CLORO')

# %% [markdown]
# En el caso del agua tratada, la tendencia previamente observada no se manifiesta de manera evidente. Sin embargo, en el parámetro de turbiedad, se logra percibir cierta indicación de esta tendencia, aunque no es tan clara como en el agua cruda.

# %% [markdown]
# ### Datos Meteorológicos

# %%
trend(2013,2016,'VEL_VIENTO')

# %% [markdown]
# Existe una correlación inversa notable entre la velocidad del viento y los parámetros de turbiedad y color. Específicamente, durante los meses en los que estos parámetros disminuyen, la velocidad del viento tiende a incrementar, y viceversa. Esta dinámica sugiere una interacción climática significativa que afecta a la calidad del agua.

# %% [markdown]
# ## Años 2016-2019

# %% [markdown]
# ### Agua Cruda

# %%
trend(2016,2020,'AGUA_CRUDA_P.H')

# %%
trend(2016,2020,'AGUA_CRUDA_NTU')

# %%
trend(2016,2020,'AGUA_CRUDA_COLOR')

# %%
trend(2016,2020,'AGUA_CRUDA_ALCALINIDAD')

# %%
trend(2016,2020,'AGUA_CRUDA_CONDUCTIVIDAD')

# %%
trend(2016,2020,'CAUDAL')

# %% [markdown]
# Se observa una notable correspondencia en las tendencias de color y turbiedad, así como una similitud entre las curvas de alcalinidad y conductividad. La recurrente tendencia anual en los parámetros de color y turbiedad se mantiene constante, al igual que en años previos. Respecto a los parámetros de alcalinidad y conductividad, que empezaron a medirse a partir de este período, se detecta un incremento gradual a partir de julio, seguido por un descenso que inicia aproximadamente en noviembre y continúa hasta enero. Esta dinámica sugiere un patrón cíclico para estos parámetros que se alinea con las variaciones estacionales.

# %% [markdown]
# ### Agua Tratada

# %%
trend(2016,2020,'AGUA_TRATADA_P.H')

# %%
trend(2016,2020,'AGUA_TRATADA_NTU')

# %%
trend(2016,2020,'AGUA_TRATADA_COLOR')

# %%
trend(2016,2020,'AGUA_TRATADA_CLORO')

# %%
trend(2016,2020,'AGUA_TRATADA_ALCALINIDAD')

# %% [markdown]
# En agua tratada las tendencias no son muy evidentes para este periodo

# %% [markdown]
# ### Datos meteorológicos

# %%
trend(2016,2020,'VEL_VIENTO')

# %%
trend(2016,2020,'PRECIPITACION')

# %% [markdown]
# La tendencia en la velocidad del viento, observada en el periodo anterior, se mantiene constante durante este intervalo de tiempo.

# %% [markdown]
# ## Años 2020-2022

# %% [markdown]
# ### Agua Cruda

# %%
trend(2020,2023,'AGUA_CRUDA_P.H')

# %%
trend(2020,2023,'AGUA_CRUDA_NTU')

# %%
trend(2020,2023,'AGUA_CRUDA_COLOR')

# %%
trend(2020,2023,'AGUA_CRUDA_ALCALINIDAD')

# %%
trend(2020,2023,'AGUA_CRUDA_CONDUCTIVIDAD')

# %%
trend(2020,2023,'CAUDAL')

# %% [markdown]
# Durante este intervalo de tiempo, la tendencia previamente observada para los parámetros de turbiedad y color empieza a difuminarse, tal y como se constata en el año 2022. No obstante, los parámetros de alcalinidad y conductividad logran mantener su tendencia anterior, con cambios que se producen aproximadamente en los mismos meses.

# %% [markdown]
# ### Datos meteorológicos

# %%
trend(2020,2023,'VEL_VIENTO')

# %%
trend(2020,2023,'PRECIPITACION')

# %%
trend(2020,2023,'PRECIPITACION2')

# %%
trend(2020,2023,'TEMP_SECA')

# %%
trend(2020,2023,'TEMP_HUMEDA')

# %% [markdown]
# Durante este intervalo temporal, se evidencia una falta de mediciones en ciertos meses para los parámetros de velocidad del viento y precipitación. Esta omisión se presenta en la estación localizada en la planta de tratamiento El Tablazo.
